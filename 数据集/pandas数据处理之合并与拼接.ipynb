# %%
import numpy as np
import pandas as pd
df_staff_1 = pd.read_excel('D:\\Python\\study\\pythontest\\pandastest\\数据集\\staff.xlsx')
df_staff_1
# Out:
#    staff_id staff_name  staff_age staff_gender  staff_salary  \
# 0         1         陈一         30            男          7000
# 1         2         周二         31            男         12000
# 2         3         张三         30            女         13000
# 3         4         李四         29            女         15000
# 4         5         王五         29            男          9000
# 5         6         赵六         35            男          8600
# 6         7         钱七         36            女          9700
# 7         8         孙八         40            女         10000
# 8         9         何九         40            男         11000
# 9        10         顾十         37            女         15000
#
#    staff_depatment_id 1级别
# 0                   1  初级
# 1                   2  高级
# 2                   3  高级
# 3                   1  高级
# 4                   2  中级
# 5                   1  中级
# 6                   3  中级
# 7                   3  中级
# 8                   1  中级
# 9                   2  高级

# %%
df_staff_2 = pd.read_excel('D:\\Python\\study\\pythontest\\pandastest\\数据集\\staff2.xlsx')
df_staff_2
# Out:
#    staff_id staff_name  staff_age staff_gender  staff_salary  \
# 0        11        韦小宝         30            男          7000
# 1        12         黄蓉         31            男         12000
# 2        13         郭靖         30            女         13000
# 3        14        张无忌         29            女         15000
#
#    staff_depatment_id 1级别
# 0                   1  初级
# 1                   2  高级
# 2                   3  高级
# 3                   1  高级

# %%
df_staff_sale_Q1=pd.read_excel('D:\\Python\\study\\pythontest\\pandastest\\数据集\\staff_sale_Q1.xlsx')
df_staff_sale_Q1
# Out:
#    staff_id staff_name      Q1
# 0         1         陈一  700000
# 1         2         周二  600000
# 2         3         张三  450000
# 3         6         赵六  340000
# 4         7         钱七  500000
# 5         8         孙八  650000
# 6         9         何九  530000
# 7        10         顾十  290000

# %%
df_staff_1.join(df_staff_sale_Q1,lsuffix='L', rsuffix='R')
# Out:
#    staff_idL staff_nameL  staff_age staff_gender  staff_salary  \
# 0          1          陈一         30            男          7000
# 1          2          周二         31            男         12000
# 2          3          张三         30            女         13000
# 3          4          李四         29            女         15000
# 4          5          王五         29            男          9000
# 5          6          赵六         35            男          8600
# 6          7          钱七         36            女          9700
# 7          8          孙八         40            女         10000
# 8          9          何九         40            男         11000
# 9         10          顾十         37            女         15000
#
#    staff_depatment_id 1级别  staff_idR staff_nameR        Q1
# 0                   1  初级        1.0          陈一  700000.0
# 1                   2  高级        2.0          周二  600000.0
# 2                   3  高级        3.0          张三  450000.0
# 3                   1  高级        6.0          赵六  340000.0
# 4                   2  中级        7.0          钱七  500000.0
# 5                   1  中级        8.0          孙八  650000.0
# 6                   3  中级        9.0          何九  530000.0
# 7                   3  中级       10.0          顾十  290000.0
# 8                   1  中级        NaN         NaN       NaN
# 9                   2  高级        NaN         NaN       NaN

# %%
df_staff_sale_Q1['staff_id'].values
# Out:
# array([ 1,  2,  3,  6,  7,  8,  9, 10], dtype=int64)

# %%
df_staff_sale_Q1.index=df_staff_sale_Q1['staff_id'].values

# %%
df_staff_sale_Q1
# Out:
#     staff_id staff_name      Q1
# 1          1         陈一  700000
# 2          2         周二  600000
# 3          3         张三  450000
# 6          6         赵六  340000
# 7          7         钱七  500000
# 8          8         孙八  650000
# 9          9         何九  530000
# 10        10         顾十  290000

# %%
df_staff_1.join(df_staff_sale_Q1,lsuffix='L', rsuffix='R')
# Out:
#    staff_idL staff_nameL  staff_age staff_gender  staff_salary  \
# 0          1          陈一         30            男          7000
# 1          2          周二         31            男         12000
# 2          3          张三         30            女         13000
# 3          4          李四         29            女         15000
# 4          5          王五         29            男          9000
# 5          6          赵六         35            男          8600
# 6          7          钱七         36            女          9700
# 7          8          孙八         40            女         10000
# 8          9          何九         40            男         11000
# 9         10          顾十         37            女         15000
#
#    staff_depatment_id 1级别  staff_idR staff_nameR        Q1
# 0                   1  初级        NaN         NaN       NaN
# 1                   2  高级        1.0          陈一  700000.0
# 2                   3  高级        2.0          周二  600000.0
# 3                   1  高级        3.0          张三  450000.0
# 4                   2  中级        NaN         NaN       NaN
# 5                   1  中级        NaN         NaN       NaN
# 6                   3  中级        6.0          赵六  340000.0
# 7                   3  中级        7.0          钱七  500000.0
# 8                   1  中级        8.0          孙八  650000.0
# 9                   2  高级        9.0          何九  530000.0

# %%
left=pd.DataFrame(['张三','李四','王五','赵六','钱七'],
                  index=[3,4,5,6,7],columns=['姓名'])
left
# Out:
#    姓名
# 3  张三
# 4  李四
# 5  王五
# 6  赵六
# 7  钱七

# %%
right=pd.DataFrame([13000,15000,9000,8600,10000],
                   index=[3,4,5,6,8],columns=['工资'])
right
# Out:
#       工资
# 3  13000
# 4  15000
# 5   9000
# 6   8600
# 8  10000

# %%
left.join(right)
# Out:
#    姓名       工资
# 3  张三  13000.0
# 4  李四  15000.0
# 5  王五   9000.0
# 6  赵六   8600.0
# 7  钱七      NaN

# %%
right.join(left)
# Out:
#       工资   姓名
# 3  13000   张三
# 4  15000   李四
# 5   9000   王五
# 6   8600   赵六
# 8  10000  NaN

# %%
left.join(right,how='right')
# Out:
#     姓名     工资
# 3   张三  13000
# 4   李四  15000
# 5   王五   9000
# 6   赵六   8600
# 8  NaN  10000

# %%
left.join(right,how='inner')
# Out:
#    姓名     工资
# 3  张三  13000
# 4  李四  15000
# 5  王五   9000
# 6  赵六   8600

# %%
left.join(right,how='outer')
# Out:
#     姓名       工资
# 3   张三  13000.0
# 4   李四  15000.0
# 5   王五   9000.0
# 6   赵六   8600.0
# 7   钱七      NaN
# 8  NaN  10000.0

# %%
left=pd.DataFrame([[3,'张三'],[4,'李四'],[5,'王五'],[6,'赵六'],[7,'钱七']],
                  columns=['编号','姓名'])
left
# Out:
#    编号  姓名
# 0   3  张三
# 1   4  李四
# 2   5  王五
# 3   6  赵六
# 4   7  钱七

# %%
right=pd.DataFrame([[3,'张三',13000],[4,'李四',15000],[5,'王五',9000],[6,'赵六',8600],[8,'孙八',10000]],
                   columns=['编号','姓名','工资'])
right
# Out:
#    编号  姓名     工资
# 0   3  张三  13000
# 1   4  李四  15000
# 2   5  王五   9000
# 3   6  赵六   8600
# 4   8  孙八  10000

# %%
pd.merge(left,right)
# Out:
#    编号  姓名     工资
# 0   3  张三  13000
# 1   4  李四  15000
# 2   5  王五   9000
# 3   6  赵六   8600

# %%
pd.merge(left,right,how='left')
# Out:
#    编号  姓名       工资
# 0   3  张三  13000.0
# 1   4  李四  15000.0
# 2   5  王五   9000.0
# 3   6  赵六   8600.0
# 4   7  钱七      NaN

# %%
pd.merge(left,right,how='outer',on=['编号','姓名'])
# Out:
#    编号  姓名       工资
# 0   3  张三  13000.0
# 1   4  李四  15000.0
# 2   5  王五   9000.0
# 3   6  赵六   8600.0
# 4   7  钱七      NaN
# 5   8  孙八  10000.0

# %%
right=pd.DataFrame([[3,'张三',13000],[4,'李四',15000],[5,'王五',9000],[6,'赵六',8600],[8,'孙八',10000]],
                   columns=['ID','姓名','工资'])
right
# Out:
#    ID  姓名     工资
# 0   3  张三  13000
# 1   4  李四  15000
# 2   5  王五   9000
# 3   6  赵六   8600
# 4   8  孙八  10000

# %%
pd.merge(left,right,how='outer',left_on='编号',right_on='ID')
# Out:
#     编号 姓名_x   ID 姓名_y       工资
# 0  3.0   张三  3.0   张三  13000.0
# 1  4.0   李四  4.0   李四  15000.0
# 2  5.0   王五  5.0   王五   9000.0
# 3  6.0   赵六  6.0   赵六   8600.0
# 4  7.0   钱七  NaN  NaN      NaN
# 5  NaN  NaN  8.0   孙八  10000.0

# %%
left2=pd.DataFrame([[1,'陈一'],[2,'周二']],columns=['编号','姓名'])
left2
# Out:
#    编号  姓名
# 0   1  陈一
# 1   2  周二

# %%
df=pd.concat([left,left2])
df
# Out:
#    编号  姓名
# 0   3  张三
# 1   4  李四
# 2   5  王五
# 3   6  赵六
# 4   7  钱七
# 0   1  陈一
# 1   2  周二

# %%
left
# Out:
#    编号  姓名
# 0   3  张三
# 1   4  李四
# 2   5  王五
# 3   6  赵六
# 4   7  钱七

# %%
right=pd.DataFrame([[3,'张三',13000],[4,'李四',15000],[5,'王五',9000],[6,'赵六',8600],[8,'孙八',10000]],
                   columns=['编号','姓名','工资'])
right
# Out:
#    编号  姓名     工资
# 0   3  张三  13000
# 1   4  李四  15000
# 2   5  王五   9000
# 3   6  赵六   8600
# 4   8  孙八  10000

# %%
df_outer=pd.concat([left,right],axis=1,join='outer')
df_outer
# Out:
#    编号  姓名  编号  姓名     工资
# 0   3  张三   3  张三  13000
# 1   4  李四   4  李四  15000
# 2   5  王五   5  王五   9000
# 3   6  赵六   6  赵六   8600
# 4   7  钱七   8  孙八  10000

# %%
df_inner=pd.concat([left,right],axis=1,join='inner')
df_inner
# Out:
#    编号  姓名  编号  姓名     工资
# 0   3  张三   3  张三  13000
# 1   4  李四   4  李四  15000
# 2   5  王五   5  王五   9000
# 3   6  赵六   6  赵六   8600
# 4   7  钱七   8  孙八  10000

# %%
left.index=left['编号'].values
right.index=right['编号'].values

# %%
df_outer=pd.concat([left,right],axis=1,join='outer')
df_outer
# Out:
#     编号   姓名   编号   姓名       工资
# 3  3.0   张三  3.0   张三  13000.0
# 4  4.0   李四  4.0   李四  15000.0
# 5  5.0   王五  5.0   王五   9000.0
# 6  6.0   赵六  6.0   赵六   8600.0
# 7  7.0   钱七  NaN  NaN      NaN
# 8  NaN  NaN  8.0   孙八  10000.0

# %%
df_inner=pd.concat([left,right],axis=1,join='inner')
df_inner
# Out:
#    编号  姓名  编号  姓名     工资
# 3   3  张三   3  张三  13000
# 4   4  李四   4  李四  15000
# 5   5  王五   5  王五   9000
# 6   6  赵六   6  赵六   8600

# %%
left
# Out:
#    编号  姓名
# 3   3  张三
# 4   4  李四
# 5   5  王五
# 6   6  赵六
# 7   7  钱七

# %%
left2=pd.DataFrame([[1,'陈一'],[2,'周二']],columns=['编号','姓名'])
left2
# Out:
#    编号  姓名
# 0   1  陈一
# 1   2  周二

# %%
left.append(left2)
# Out:
#    编号  姓名
# 3   3  张三
# 4   4  李四
# 5   5  王五
# 6   6  赵六
# 7   7  钱七
# 0   1  陈一
# 1   2  周二

# %%
left3=pd.DataFrame([[8,'孙八',10000],[9,'何九',15000]],columns=['编号','姓名','工资'])
left3
# Out:
#    编号  姓名     工资
# 0   8  孙八  10000
# 1   9  何九  15000

# %%
left.append(left3)
# Out:
#    编号  姓名       工资
# 3   3  张三      NaN
# 4   4  李四      NaN
# 5   5  王五      NaN
# 6   6  赵六      NaN
# 7   7  钱七      NaN
# 0   8  孙八  10000.0
# 1   9  何九  15000.0

# %%
left.append([left2,left3])
# Out:
#    编号  姓名       工资
# 3   3  张三      NaN
# 4   4  李四      NaN
# 5   5  王五      NaN
# 6   6  赵六      NaN
# 7   7  钱七      NaN
# 0   1  陈一      NaN
# 1   2  周二      NaN
# 0   8  孙八  10000.0
# 1   9  何九  15000.0

# %%
df_staff=left.append(left3)
df_staff
# Out:
#    编号  姓名       工资
# 3   3  张三      NaN
# 4   4  李四      NaN
# 5   5  王五      NaN
# 6   6  赵六      NaN
# 7   7  钱七      NaN
# 0   8  孙八  10000.0
# 1   9  何九  15000.0

# %%
left.combine_first(right)
# Out:
#    姓名       工资   编号
# 3  张三  13000.0  3.0
# 4  李四  15000.0  4.0
# 5  王五   9000.0  5.0
# 6  赵六   8600.0  6.0
# 7  钱七      NaN  7.0
# 8  孙八  10000.0  8.0

# %%
left.combine_first(right)
# Out:
#     编号  姓名       工资
# 3  3.0  张三  13000.0
# 4  4.0  李四  15000.0
# 5  5.0  王五   9000.0
# 6  6.0  赵六   8600.0
# 7  7.0  钱七      NaN
# 8  8.0  孙八  10000.0

# %%
left['工资']=np.NaN #为了演示，增加为空的工资列，没有工资列，用right填充同样的效果
left
# Out:
#    编号  姓名  工资
# 3   3  张三 NaN
# 4   4  李四 NaN
# 5   5  王五 NaN
# 6   6  赵六 NaN
# 7   7  钱七 NaN

# %%
right
# Out:
#    编号  姓名     工资
# 3   3  张三  13000
# 4   4  李四  15000
# 5   5  王五   9000
# 6   6  赵六   8600
# 8   8  孙八  10000

# %%
left.combine_first(right) #用right去填充left
# Out:
#     编号  姓名       工资
# 3  3.0  张三  13000.0
# 4  4.0  李四  15000.0
# 5  5.0  王五   9000.0
# 6  6.0  赵六   8600.0
# 7  7.0  钱七      NaN
# 8  8.0  孙八  10000.0

# %%
left
# Out:
#    编号  姓名  工资
# 3   3  张三 NaN
# 4   4  李四 NaN
# 5   5  王五 NaN
# 6   6  赵六 NaN
# 7   7  钱七 NaN

# %%
left.update(right)
left
# Out:
#     编号  姓名       工资
# 3  3.0  张三  13000.0
# 4  4.0  李四  15000.0
# 5  5.0  王五   9000.0
# 6  6.0  赵六   8600.0
# 7  7.0  钱七      NaN
