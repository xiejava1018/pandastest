# %%
import numpy as np
import pandas as pd
df = pd.read_excel('D:\\Python\\study\\pythontest\\pandastest\\数据集\\student.xlsx')
df
# Out:
#    1-学号 2-姓名  3-年龄  4-语文  5-数学  6-英语  班级  性别 是否接种  表现
# 0     1   陈一    12    90    95    90  一班   1    已  良好
# 1     2   周二    12    91   100    99  一班   2    是  优秀
# 2     3   张三    13    96    99    99  一班   1    否  优秀
# 3     4   李四    14    97    99    98  一班   2    已  优秀
# 4     5   王五    12    96    98    97  一班   1    是  良好
# 5     6   赵六    12    95    97    99  二班   2    是  良好
# 6     7   钱七    13    90    99    96  二班   1  NaN  良好
# 7     8   孙八    13    93    96    97  二班   2    是  良好
# 8     9   何九    14    94    97    95  二班   1    有  良好
# 9    10   顾十    12    96    96    96  二班   2    是  良好

# %%
df['性别']
# Out:
# 0    1
# 1    2
# 2    1
# 3    2
# 4    1
# 5    2
# 6    1
# 7    2
# 8    1
# 9    2
# Name: 性别, dtype: int64

# %%
gender_map={1:'男',2:'女'}
df['性别']=df['性别'].map(gender_map)
df
# Out:
#    1-学号 2-姓名  3-年龄  4-语文  5-数学  6-英语  班级 性别 是否接种  表现
# 0     1   陈一    12    90    95    90  一班  男    已  良好
# 1     2   周二    12    91   100    99  一班  女    是  优秀
# 2     3   张三    13    96    99    99  一班  男    否  优秀
# 3     4   李四    14    97    99    98  一班  女    已  优秀
# 4     5   王五    12    96    98    97  一班  男    是  良好
# 5     6   赵六    12    95    97    99  二班  女    是  良好
# 6     7   钱七    13    90    99    96  二班  男  NaN  良好
# 7     8   孙八    13    93    96    97  二班  女    是  良好
# 8     9   何九    14    94    97    95  二班  男    有  良好
# 9    10   顾十    12    96    96    96  二班  女    是  良好

# %%
df['性别']
# Out:
# 0    男
# 1    女
# 2    男
# 3    女
# 4    男
# 5    女
# 6    男
# 7    女
# 8    男
# 9    女
# Name: 性别, dtype: object

# %%
df['数学等级']=df['5-数学'].map(lambda x:'优秀' if x>95 else '良好')
df
# Out:
#    1-学号 2-姓名  3-年龄  4-语文  5-数学  6-英语  班级 性别 是否接种  表现 数学等级
# 0     1   陈一    12    90    95    90  一班  男    已  良好   良好
# 1     2   周二    12    91   100    99  一班  女    是  优秀   优秀
# 2     3   张三    13    96    99    99  一班  男    否  优秀   优秀
# 3     4   李四    14    97    99    98  一班  女    已  优秀   优秀
# 4     5   王五    12    96    98    97  一班  男    是  良好   优秀
# 5     6   赵六    12    95    97    99  二班  女    是  良好   优秀
# 6     7   钱七    13    90    99    96  二班  男  NaN  良好   优秀
# 7     8   孙八    13    93    96    97  二班  女    是  良好   优秀
# 8     9   何九    14    94    97    95  二班  男    有  良好   优秀
# 9    10   顾十    12    96    96    96  二班  女    是  良好   优秀

# %%
def score(x):
    score_class='良好'
    if x>95:
        score_class='优秀'
    return score_class
df['语文等级']=df['4-语文'].map(score)
df
# Out:
#    1-学号 2-姓名  3-年龄  4-语文  5-数学  6-英语  班级 性别 是否接种  表现 数学等级 语文等级
# 0     1   陈一    12    90    95    90  一班  男    已  良好   良好   良好
# 1     2   周二    12    91   100    99  一班  女    是  优秀   优秀   良好
# 2     3   张三    13    96    99    99  一班  男    否  优秀   优秀   优秀
# 3     4   李四    14    97    99    98  一班  女    已  优秀   优秀   优秀
# 4     5   王五    12    96    98    97  一班  男    是  良好   优秀   优秀
# 5     6   赵六    12    95    97    99  二班  女    是  良好   优秀   良好
# 6     7   钱七    13    90    99    96  二班  男  NaN  良好   优秀   良好
# 7     8   孙八    13    93    96    97  二班  女    是  良好   优秀   良好
# 8     9   何九    14    94    97    95  二班  男    有  良好   优秀   良好
# 9    10   顾十    12    96    96    96  二班  女    是  良好   优秀   优秀

# %%
df.replace(['优秀','良好'],['优','良'])
# Out:
#    1-学号 2-姓名  3-年龄  4-语文  5-数学  6-英语  班级 性别 是否接种 表现 数学等级 语文等级
# 0     1   陈一    12    90    95    90  一班  男    已  良    良    良
# 1     2   周二    12    91   100    99  一班  女    是  优    优    良
# 2     3   张三    13    96    99    99  一班  男    否  优    优    优
# 3     4   李四    14    97    99    98  一班  女    已  优    优    优
# 4     5   王五    12    96    98    97  一班  男    是  良    优    优
# 5     6   赵六    12    95    97    99  二班  女    是  良    优    良
# 6     7   钱七    13    90    99    96  二班  男  NaN  良    优    良
# 7     8   孙八    13    93    96    97  二班  女    是  良    优    良
# 8     9   何九    14    94    97    95  二班  男    有  良    优    良
# 9    10   顾十    12    96    96    96  二班  女    是  良    优    优

# %%
df
# Out:
#    1-学号 2-姓名  3-年龄  4-语文  5-数学  6-英语  班级 性别 是否接种  表现 数学等级 语文等级
# 0     1   陈一    12    90    95    90  一班  男    已  良好   良好   良好
# 1     2   周二    12    91   100    99  一班  女    是  优秀   优秀   良好
# 2     3   张三    13    96    99    99  一班  男    否  优秀   优秀   优秀
# 3     4   李四    14    97    99    98  一班  女    已  优秀   优秀   优秀
# 4     5   王五    12    96    98    97  一班  男    是  良好   优秀   优秀
# 5     6   赵六    12    95    97    99  二班  女    是  良好   优秀   良好
# 6     7   钱七    13    90    99    96  二班  男  NaN  良好   优秀   良好
# 7     8   孙八    13    93    96    97  二班  女    是  良好   优秀   良好
# 8     9   何九    14    94    97    95  二班  男    有  良好   优秀   良好
# 9    10   顾十    12    96    96    96  二班  女    是  良好   优秀   优秀

# %%
df.replace(['已',np.nan],['是','否'])
# Out:
#    1-学号 2-姓名  3-年龄  4-语文  5-数学  6-英语  班级 性别 是否接种  表现 数学等级 语文等级
# 0     1   陈一    12    90    95    90  一班  男    是  良好   良好   良好
# 1     2   周二    12    91   100    99  一班  女    是  优秀   优秀   良好
# 2     3   张三    13    96    99    99  一班  男    否  优秀   优秀   优秀
# 3     4   李四    14    97    99    98  一班  女    是  优秀   优秀   优秀
# 4     5   王五    12    96    98    97  一班  男    是  良好   优秀   优秀
# 5     6   赵六    12    95    97    99  二班  女    是  良好   优秀   良好
# 6     7   钱七    13    90    99    96  二班  男    否  良好   优秀   良好
# 7     8   孙八    13    93    96    97  二班  女    是  良好   优秀   良好
# 8     9   何九    14    94    97    95  二班  男    有  良好   优秀   良好
# 9    10   顾十    12    96    96    96  二班  女    是  良好   优秀   优秀

# %%
df[df['6-英语']>95]
# Out:
#    1-学号 2-姓名  3-年龄  4-语文  5-数学  6-英语  班级 性别 是否接种  表现 数学等级 语文等级
# 1     2   周二    12    91   100    99  一班  女    是  优秀   优秀   良好
# 2     3   张三    13    96    99    99  一班  男    否  优秀   优秀   优秀
# 3     4   李四    14    97    99    98  一班  女    已  优秀   优秀   优秀
# 4     5   王五    12    96    98    97  一班  男    是  良好   优秀   优秀
# 5     6   赵六    12    95    97    99  二班  女    是  良好   优秀   良好
# 6     7   钱七    13    90    99    96  二班  男  NaN  良好   优秀   良好
# 7     8   孙八    13    93    96    97  二班  女    是  良好   优秀   良好
# 9    10   顾十    12    96    96    96  二班  女    是  良好   优秀   优秀

# %%
df.query('6-英语 >95')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# D:\Anaconda3\lib\site-packages\pandas\core\computation\scope.py in resolve(self, key, is_local)
#     200             if self.has_resolvers:
# --> 201                 return self.resolvers[key]
#     202
#
# D:\Anaconda3\lib\collections\__init__.py in __getitem__(self, key)
#     897                 pass
# --> 898         return self.__missing__(key)            # support subclasses that define __missing__
#     899
#
# D:\Anaconda3\lib\collections\__init__.py in __missing__(self, key)
#     889     def __missing__(self, key):
# --> 890         raise KeyError(key)
#     891
#
# KeyError: '英语'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# D:\Anaconda3\lib\site-packages\pandas\core\computation\scope.py in resolve(self, key, is_local)
#     211                 # e.g., df[df > 0]
# --> 212                 return self.temps[key]
#     213             except KeyError as err:
#
# KeyError: '英语'
#
# The above exception was the direct cause of the following exception:
#
# UndefinedVariableError                    Traceback (most recent call last)
# <ipython-input-119-a8b092e69d2f> in <module>
# ----> 1 df.query('6-英语 >95')
#
# D:\Anaconda3\lib\site-packages\pandas\core\frame.py in query(self, expr, inplace, **kwargs)
#    3467         kwargs["level"] = kwargs.pop("level", 0) + 1
#    3468         kwargs["target"] = None
# -> 3469         res = self.eval(expr, **kwargs)
#    3470
#    3471         try:
#
# D:\Anaconda3\lib\site-packages\pandas\core\frame.py in eval(self, expr, inplace, **kwargs)
#    3597         kwargs["resolvers"] = kwargs.get("resolvers", ()) + tuple(resolvers)
#    3598
# -> 3599         return _eval(expr, inplace=inplace, **kwargs)
#    3600
#    3601     def select_dtypes(self, include=None, exclude=None) -> DataFrame:
#
# D:\Anaconda3\lib\site-packages\pandas\core\computation\eval.py in eval(expr, parser, engine, truediv, local_dict, global_dict, resolvers, level, target, inplace)
#     340         )
#     341
# --> 342         parsed_expr = Expr(expr, engine=engine, parser=parser, env=env)
#     343
#     344         # construct the engine and evaluate the parsed expression
#
# D:\Anaconda3\lib\site-packages\pandas\core\computation\expr.py in __init__(self, expr, engine, parser, env, level)
#     796         self.parser = parser
#     797         self._visitor = PARSERS[parser](self.env, self.engine, self.parser)
# --> 798         self.terms = self.parse()
#     799
#     800     @property
#
# D:\Anaconda3\lib\site-packages\pandas\core\computation\expr.py in parse(self)
#     815         Parse an expression.
#     816         """
# --> 817         return self._visitor.visit(self.expr)
#     818
#     819     @property
#
# D:\Anaconda3\lib\site-packages\pandas\core\computation\expr.py in visit(self, node, **kwargs)
#     399         method = "visit_" + type(node).__name__
#     400         visitor = getattr(self, method)
# --> 401         return visitor(node, **kwargs)
#     402
#     403     def visit_Module(self, node, **kwargs):
#
# D:\Anaconda3\lib\site-packages\pandas\core\computation\expr.py in visit_Module(self, node, **kwargs)
#     405             raise SyntaxError("only a single expression is allowed")
#     406         expr = node.body[0]
# --> 407         return self.visit(expr, **kwargs)
#     408
#     409     def visit_Expr(self, node, **kwargs):
#
# D:\Anaconda3\lib\site-packages\pandas\core\computation\expr.py in visit(self, node, **kwargs)
#     399         method = "visit_" + type(node).__name__
#     400         visitor = getattr(self, method)
# --> 401         return visitor(node, **kwargs)
#     402
#     403     def visit_Module(self, node, **kwargs):
#
# D:\Anaconda3\lib\site-packages\pandas\core\computation\expr.py in visit_Expr(self, node, **kwargs)
#     408
#     409     def visit_Expr(self, node, **kwargs):
# --> 410         return self.visit(node.value, **kwargs)
#     411
#     412     def _rewrite_membership_op(self, node, left, right):
#
# D:\Anaconda3\lib\site-packages\pandas\core\computation\expr.py in visit(self, node, **kwargs)
#     399         method = "visit_" + type(node).__name__
#     400         visitor = getattr(self, method)
# --> 401         return visitor(node, **kwargs)
#     402
#     403     def visit_Module(self, node, **kwargs):
#
# D:\Anaconda3\lib\site-packages\pandas\core\computation\expr.py in visit_Compare(self, node, **kwargs)
#     708             op = self.translate_In(ops[0])
#     709             binop = ast.BinOp(op=op, left=node.left, right=comps[0])
# --> 710             return self.visit(binop)
#     711
#     712         # recursive case: we have a chained comparison, a CMP b CMP c, etc.
#
# D:\Anaconda3\lib\site-packages\pandas\core\computation\expr.py in visit(self, node, **kwargs)
#     399         method = "visit_" + type(node).__name__
#     400         visitor = getattr(self, method)
# --> 401         return visitor(node, **kwargs)
#     402
#     403     def visit_Module(self, node, **kwargs):
#
# D:\Anaconda3\lib\site-packages\pandas\core\computation\expr.py in visit_BinOp(self, node, **kwargs)
#     520
#     521     def visit_BinOp(self, node, **kwargs):
# --> 522         op, op_class, left, right = self._maybe_transform_eq_ne(node)
#     523         left, right = self._maybe_downcast_constants(left, right)
#     524         return self._maybe_evaluate_binop(op, op_class, left, right)
#
# D:\Anaconda3\lib\site-packages\pandas\core\computation\expr.py in _maybe_transform_eq_ne(self, node, left, right)
#     440     def _maybe_transform_eq_ne(self, node, left=None, right=None):
#     441         if left is None:
# --> 442             left = self.visit(node.left, side="left")
#     443         if right is None:
#     444             right = self.visit(node.right, side="right")
#
# D:\Anaconda3\lib\site-packages\pandas\core\computation\expr.py in visit(self, node, **kwargs)
#     399         method = "visit_" + type(node).__name__
#     400         visitor = getattr(self, method)
# --> 401         return visitor(node, **kwargs)
#     402
#     403     def visit_Module(self, node, **kwargs):
#
# D:\Anaconda3\lib\site-packages\pandas\core\computation\expr.py in visit_BinOp(self, node, **kwargs)
#     520
#     521     def visit_BinOp(self, node, **kwargs):
# --> 522         op, op_class, left, right = self._maybe_transform_eq_ne(node)
#     523         left, right = self._maybe_downcast_constants(left, right)
#     524         return self._maybe_evaluate_binop(op, op_class, left, right)
#
# D:\Anaconda3\lib\site-packages\pandas\core\computation\expr.py in _maybe_transform_eq_ne(self, node, left, right)
#     442             left = self.visit(node.left, side="left")
#     443         if right is None:
# --> 444             right = self.visit(node.right, side="right")
#     445         op, op_class, left, right = self._rewrite_membership_op(node, left, right)
#     446         return op, op_class, left, right
#
# D:\Anaconda3\lib\site-packages\pandas\core\computation\expr.py in visit(self, node, **kwargs)
#     399         method = "visit_" + type(node).__name__
#     400         visitor = getattr(self, method)
# --> 401         return visitor(node, **kwargs)
#     402
#     403     def visit_Module(self, node, **kwargs):
#
# D:\Anaconda3\lib\site-packages\pandas\core\computation\expr.py in visit_Name(self, node, **kwargs)
#     533
#     534     def visit_Name(self, node, **kwargs):
# --> 535         return self.term_type(node.id, self.env, **kwargs)
#     536
#     537     def visit_NameConstant(self, node, **kwargs):
#
# D:\Anaconda3\lib\site-packages\pandas\core\computation\ops.py in __init__(self, name, env, side, encoding)
#      84         tname = str(name)
#      85         self.is_local = tname.startswith(LOCAL_TAG) or tname in DEFAULT_GLOBALS
# ---> 86         self._value = self._resolve_name()
#      87         self.encoding = encoding
#      88
#
# D:\Anaconda3\lib\site-packages\pandas\core\computation\ops.py in _resolve_name(self)
#     101
#     102     def _resolve_name(self):
# --> 103         res = self.env.resolve(self.local_name, is_local=self.is_local)
#     104         self.update(res)
#     105
#
# D:\Anaconda3\lib\site-packages\pandas\core\computation\scope.py in resolve(self, key, is_local)
#     215                 from pandas.core.computation.ops import UndefinedVariableError
#     216
# --> 217                 raise UndefinedVariableError(key, is_local) from err
#     218
#     219     def swapkey(self, old_key: str, new_key: str, new_value=None):
#
# UndefinedVariableError: name '英语' is not defined

# %%
df.rename(columns={'6-英语':'english'},inplace=True)
df.query('english > 95')
# Out:
#    1-学号 2-姓名  3-年龄  4-语文  5-数学  english  班级 性别 是否接种  表现 数学等级 语文等级
# 1     2   周二    12    91   100       99  一班  女    是  优秀   优秀   良好
# 2     3   张三    13    96    99       99  一班  男    否  优秀   优秀   优秀
# 3     4   李四    14    97    99       98  一班  女    已  优秀   优秀   优秀
# 4     5   王五    12    96    98       97  一班  男    是  良好   优秀   优秀
# 5     6   赵六    12    95    97       99  二班  女    是  良好   优秀   良好
# 6     7   钱七    13    90    99       96  二班  男  NaN  良好   优秀   良好
# 7     8   孙八    13    93    96       97  二班  女    是  良好   优秀   良好
# 9    10   顾十    12    96    96       96  二班  女    是  良好   优秀   优秀

# %%
df.english> 95
# Out:
# 0    False
# 1     True
# 2     True
# 3     True
# 4     True
# 5     True
# 6     True
# 7     True
# 8    False
# 9     True
# Name: english, dtype: bool

# %%
df[['1-学号','2-姓名','3-年龄']]
# Out:
#    1-学号 2-姓名  3-年龄
# 0     1   陈一    12
# 1     2   周二    12
# 2     3   张三    13
# 3     4   李四    14
# 4     5   王五    12
# 5     6   赵六    12
# 6     7   钱七    13
# 7     8   孙八    13
# 8     9   何九    14
# 9    10   顾十    12

# %%
df[['1-学号','2-姓名','3-年龄']].rename(columns={'1-学号':'ID','2-姓名':'name','3-年龄':'age'})
# Out:
#    ID name  age
# 0   1   陈一   12
# 1   2   周二   12
# 2   3   张三   13
# 3   4   李四   14
# 4   5   王五   12
# 5   6   赵六   12
# 6   7   钱七   13
# 7   8   孙八   13
# 8   9   何九   14
# 9  10   顾十   12
